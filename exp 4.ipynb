# %%
import numpy as np

# Example quarterly sales data (replace with your actual data)
sales_data = np.array([150000, 175000, 200000, 250000])

# 1️⃣ Total sales for the year
total_sales = np.sum(sales_data)

# 2️⃣ Percentage increase from Q1 to Q4
first_quarter = sales_data[0]
fourth_quarter = sales_data[3]

percentage_increase = ((fourth_quarter - first_quarter) / first_quarter) * 100

# Print results
print("Total Sales for the Year:", total_sales)
print("Percentage Increase from Q1 to Q4:", percentage_increase, "%")
# Out:
# Total Sales for the Year: 775000
# Percentage Increase from Q1 to Q4: 66.66666666666666 %
